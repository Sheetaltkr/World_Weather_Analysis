# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 620

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a78aef3c21441b603da189739a03963

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | alakurtti
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | upernavik
# Processing Record 4 of Set 1 | pevek
# Processing Record 5 of Set 1 | bluff
# Processing Record 6 of Set 1 | paita
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | bengkulu
# Processing Record 9 of Set 1 | hithadhoo
# Processing Record 10 of Set 1 | praia da vitoria
# Processing Record 11 of Set 1 | sinjai
# Processing Record 12 of Set 1 | avarua
# Processing Record 13 of Set 1 | ilulissat
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | cherskiy
# Processing Record 16 of Set 1 | verkhovyna
# Processing Record 17 of Set 1 | fukue
# Processing Record 18 of Set 1 | shelburne
# Processing Record 19 of Set 1 | kidal
# Processing Record 20 of Set 1 | klaksvik
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | ambon
# Processing Record 23 of Set 1 | havoysund
# Processing Record 24 of Set 1 | hobart
# Processing Record 25 of Set 1 | port alfred
# Processing Record 26 of Set 1 | isangel
# Processing Record 27 of Set 1 | ushuaia
# Processing Record 28 of Set 1 | henties bay
# Processing Record 29 of Set 1 | poum
# Processing Record 30 of Set 1 | soyo
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | nhulunbuy
# Processing Record 33 of Set 1 | busselton
# Processing Record 34 of Set 1 | xining
# Processing Record 35 of Set 1 | arraial do cabo
# Processing Record 36 of Set 1 | wanning
# Processing Record 37 of Set 1 | te anau
# Processing Record 38 of Set 1 | chumikan
# Processing Record 39 of Set 1 | jamestown
# Processing Record 40 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 41 of Set 1 | harper
# Processing Record 42 of Set 1 | vuktyl
# Processing Record 43 of Set 1 | pocatello
# Processing Record 44 of Set 1 | namibe
# Processing Record 45 of Set 1 | yershichi
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | ribeira grande
# Processing Record 48 of Set 1 | mataura
# Processing Record 49 of Set 1 | sioux lookout
# Processing Record 50 of Set 1 | honavar
# Processing Record 1 of Set 2 | saint george
# Processing Record 2 of Set 2 | yellowknife
# Processing Record 3 of Set 2 | vaini
# Processing Record 4 of Set 2 | tasbuget
# City not found. Skipping...
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | bambous virieux
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | excelsior springs
# Processing Record 9 of Set 2 | geraldton
# Processing Record 10 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 11 of Set 2 | kupang
# Processing Record 12 of Set 2 | clyde
# Processing Record 13 of Set 2 | acuna
# City not found. Skipping...
# Processing Record 14 of Set 2 | tonj
# Processing Record 15 of Set 2 | qui nhon
# Processing Record 16 of Set 2 | doka
# Processing Record 17 of Set 2 | grand gaube
# Processing Record 18 of Set 2 | livingston
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 21 of Set 2 | jacareacanga
# Processing Record 22 of Set 2 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 24 of Set 2 | kaitangata
# Processing Record 25 of Set 2 | general roca
# Processing Record 26 of Set 2 | qaanaaq
# Processing Record 27 of Set 2 | bitung
# Processing Record 28 of Set 2 | gazanjyk
# Processing Record 29 of Set 2 | makung
# City not found. Skipping...
# Processing Record 30 of Set 2 | tovuz
# Processing Record 31 of Set 2 | khasan
# Processing Record 32 of Set 2 | vestmannaeyjar
# Processing Record 33 of Set 2 | victoria point
# Processing Record 34 of Set 2 | posse
# Processing Record 35 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 2 | utiroa
# City not found. Skipping...
# Processing Record 37 of Set 2 | souillac
# Processing Record 38 of Set 2 | macaboboni
# City not found. Skipping...
# Processing Record 39 of Set 2 | avera
# Processing Record 40 of Set 2 | thompson
# Processing Record 41 of Set 2 | kenora
# Processing Record 42 of Set 2 | ucluelet
# Processing Record 43 of Set 2 | nikolskoye
# Processing Record 44 of Set 2 | khandbari
# Processing Record 45 of Set 2 | puerto ayora
# Processing Record 46 of Set 2 | cabo san lucas
# Processing Record 47 of Set 2 | touros
# Processing Record 48 of Set 2 | nome
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | hervey bay
# Processing Record 1 of Set 3 | kiboga
# Processing Record 2 of Set 3 | lazaro cardenas
# Processing Record 3 of Set 3 | carnarvon
# Processing Record 4 of Set 3 | aykhal
# Processing Record 5 of Set 3 | dingle
# Processing Record 6 of Set 3 | porbandar
# Processing Record 7 of Set 3 | silvania
# Processing Record 8 of Set 3 | jawad
# Processing Record 9 of Set 3 | la romana
# Processing Record 10 of Set 3 | tecoanapa
# Processing Record 11 of Set 3 | nowy dwor gdanski
# Processing Record 12 of Set 3 | provideniya
# Processing Record 13 of Set 3 | korla
# Processing Record 14 of Set 3 | cap-aux-meules
# Processing Record 15 of Set 3 | serabu
# Processing Record 16 of Set 3 | fortuna
# Processing Record 17 of Set 3 | talcahuano
# Processing Record 18 of Set 3 | constantine
# Processing Record 19 of Set 3 | ponta do sol
# Processing Record 20 of Set 3 | mahebourg
# Processing Record 21 of Set 3 | marawi
# Processing Record 22 of Set 3 | mount isa
# Processing Record 23 of Set 3 | ixtapa
# Processing Record 24 of Set 3 | deoli
# Processing Record 25 of Set 3 | lompoc
# Processing Record 26 of Set 3 | constitucion
# Processing Record 27 of Set 3 | lumeje
# Processing Record 28 of Set 3 | shingu
# Processing Record 29 of Set 3 | chuy
# Processing Record 30 of Set 3 | butaritari
# Processing Record 31 of Set 3 | hilo
# Processing Record 32 of Set 3 | okhotsk
# Processing Record 33 of Set 3 | atuona
# Processing Record 34 of Set 3 | kungurtug
# Processing Record 35 of Set 3 | sira
# Processing Record 36 of Set 3 | bikin
# Processing Record 37 of Set 3 | sao filipe
# Processing Record 38 of Set 3 | komsomolskiy
# Processing Record 39 of Set 3 | cidreira
# Processing Record 40 of Set 3 | vila franca do campo
# Processing Record 41 of Set 3 | hasaki
# Processing Record 42 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 3 | san patricio
# Processing Record 44 of Set 3 | burica
# City not found. Skipping...
# Processing Record 45 of Set 3 | derzhavinsk
# Processing Record 46 of Set 3 | tabligbo
# Processing Record 47 of Set 3 | krasnoselkup
# Processing Record 48 of Set 3 | aklavik
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | chalus
# Processing Record 1 of Set 4 | ola
# Processing Record 2 of Set 4 | caravelas
# Processing Record 3 of Set 4 | port lincoln
# Processing Record 4 of Set 4 | talakan
# Processing Record 5 of Set 4 | bilibino
# Processing Record 6 of Set 4 | rancho palos verdes
# Processing Record 7 of Set 4 | meyungs
# City not found. Skipping...
# Processing Record 8 of Set 4 | vigrestad
# Processing Record 9 of Set 4 | portland
# Processing Record 10 of Set 4 | menongue
# Processing Record 11 of Set 4 | trinidad
# Processing Record 12 of Set 4 | bereda
# Processing Record 13 of Set 4 | mogadishu
# Processing Record 14 of Set 4 | chupei
# City not found. Skipping...
# Processing Record 15 of Set 4 | port-gentil
# Processing Record 16 of Set 4 | am timan
# Processing Record 17 of Set 4 | ruatoria
# City not found. Skipping...
# Processing Record 18 of Set 4 | bhaktapur
# Processing Record 19 of Set 4 | tuktoyaktuk
# Processing Record 20 of Set 4 | trenggalek
# Processing Record 21 of Set 4 | chokurdakh
# Processing Record 22 of Set 4 | shache
# Processing Record 23 of Set 4 | georgetown
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | davila
# Processing Record 26 of Set 4 | vardo
# Processing Record 27 of Set 4 | balikpapan
# Processing Record 28 of Set 4 | lisakovsk
# Processing Record 29 of Set 4 | mount gambier
# Processing Record 30 of Set 4 | adrar
# Processing Record 31 of Set 4 | grindavik
# Processing Record 32 of Set 4 | kandrian
# Processing Record 33 of Set 4 | beyneu
# Processing Record 34 of Set 4 | nakusp
# Processing Record 35 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 36 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 37 of Set 4 | zverinogolovskoye
# Processing Record 38 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 39 of Set 4 | mbala
# Processing Record 40 of Set 4 | langsa
# Processing Record 41 of Set 4 | ondorhaan
# City not found. Skipping...
# Processing Record 42 of Set 4 | tagab
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | ulaanbaatar
# Processing Record 45 of Set 4 | merauke
# Processing Record 46 of Set 4 | kracheh
# City not found. Skipping...
# Processing Record 47 of Set 4 | saint-augustin
# Processing Record 48 of Set 4 | mecca
# Processing Record 49 of Set 4 | zyryanka
# Processing Record 50 of Set 4 | noumea
# Processing Record 1 of Set 5 | barrow
# Processing Record 2 of Set 5 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 5 | manzanillo
# Processing Record 4 of Set 5 | vostok
# Processing Record 5 of Set 5 | rochester
# Processing Record 6 of Set 5 | guangyuan
# Processing Record 7 of Set 5 | sobolevo
# Processing Record 8 of Set 5 | miracema do tocantins
# Processing Record 9 of Set 5 | marzuq
# Processing Record 10 of Set 5 | longyearbyen
# Processing Record 11 of Set 5 | pacific grove
# Processing Record 12 of Set 5 | kavaratti
# Processing Record 13 of Set 5 | san juan
# Processing Record 14 of Set 5 | colonia
# Processing Record 15 of Set 5 | iskateley
# Processing Record 16 of Set 5 | lebu
# Processing Record 17 of Set 5 | altus
# Processing Record 18 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 5 | saint-philippe
# Processing Record 20 of Set 5 | umm kaddadah
# Processing Record 21 of Set 5 | santiago del estero
# Processing Record 22 of Set 5 | lyuban
# Processing Record 23 of Set 5 | great bend
# Processing Record 24 of Set 5 | castro
# Processing Record 25 of Set 5 | ayagoz
# Processing Record 26 of Set 5 | limbuhan
# Processing Record 27 of Set 5 | karla
# Processing Record 28 of Set 5 | pochutla
# Processing Record 29 of Set 5 | herat
# Processing Record 30 of Set 5 | puri
# Processing Record 31 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 32 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 5 | tasiilaq
# Processing Record 34 of Set 5 | kruisfontein
# Processing Record 35 of Set 5 | danville
# Processing Record 36 of Set 5 | posadas
# Processing Record 37 of Set 5 | dinghai
# Processing Record 38 of Set 5 | codrington
# Processing Record 39 of Set 5 | takoradi
# Processing Record 40 of Set 5 | karratha
# Processing Record 41 of Set 5 | melo
# Processing Record 42 of Set 5 | bathsheba
# Processing Record 43 of Set 5 | airai
# Processing Record 44 of Set 5 | bredasdorp
# Processing Record 45 of Set 5 | vila velha
# Processing Record 46 of Set 5 | los llanos de aridane
# Processing Record 47 of Set 5 | ketchikan
# Processing Record 48 of Set 5 | kapit
# Processing Record 49 of Set 5 | oktyabrskoye
# Processing Record 50 of Set 5 | esperance
# Processing Record 1 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 2 of Set 6 | port hardy
# Processing Record 3 of Set 6 | cervo
# Processing Record 4 of Set 6 | suluq
# Processing Record 5 of Set 6 | hofn
# Processing Record 6 of Set 6 | clyde river
# Processing Record 7 of Set 6 | ferme-neuve
# Processing Record 8 of Set 6 | padang
# Processing Record 9 of Set 6 | tautira
# Processing Record 10 of Set 6 | verkhoyansk
# Processing Record 11 of Set 6 | westport
# Processing Record 12 of Set 6 | kahului
# Processing Record 13 of Set 6 | berlevag
# Processing Record 14 of Set 6 | joshimath
# Processing Record 15 of Set 6 | ahipara
# Processing Record 16 of Set 6 | ust-nera
# Processing Record 17 of Set 6 | nangong
# Processing Record 18 of Set 6 | russell
# Processing Record 19 of Set 6 | iqaluit
# Processing Record 20 of Set 6 | moorhead
# Processing Record 21 of Set 6 | pangai
# Processing Record 22 of Set 6 | narsaq
# Processing Record 23 of Set 6 | billings
# Processing Record 24 of Set 6 | khatanga
# Processing Record 25 of Set 6 | berdigestyakh
# Processing Record 26 of Set 6 | capusu mare
# Processing Record 27 of Set 6 | kadoma
# Processing Record 28 of Set 6 | kodiak
# Processing Record 29 of Set 6 | roma
# Processing Record 30 of Set 6 | namanga
# Processing Record 31 of Set 6 | saskylakh
# Processing Record 32 of Set 6 | teguldet
# Processing Record 33 of Set 6 | lodwar
# Processing Record 34 of Set 6 | katsuura
# Processing Record 35 of Set 6 | virden
# Processing Record 36 of Set 6 | chifeng
# Processing Record 37 of Set 6 | dharchula
# Processing Record 38 of Set 6 | la ronge
# Processing Record 39 of Set 6 | mar del plata
# Processing Record 40 of Set 6 | taltal
# Processing Record 41 of Set 6 | havre
# Processing Record 42 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 43 of Set 6 | bethel
# Processing Record 44 of Set 6 | belyy yar
# Processing Record 45 of Set 6 | taft
# Processing Record 46 of Set 6 | milos
# Processing Record 47 of Set 6 | kemi
# Processing Record 48 of Set 6 | puerto varas
# Processing Record 49 of Set 6 | lomovka
# Processing Record 50 of Set 6 | matamoros
# Processing Record 1 of Set 7 | aripuana
# Processing Record 2 of Set 7 | gat
# Processing Record 3 of Set 7 | suntar
# Processing Record 4 of Set 7 | naze
# Processing Record 5 of Set 7 | mazagao
# Processing Record 6 of Set 7 | pisco
# Processing Record 7 of Set 7 | borlange
# City not found. Skipping...
# Processing Record 8 of Set 7 | atyashevo
# Processing Record 9 of Set 7 | sitka
# Processing Record 10 of Set 7 | mogzon
# Processing Record 11 of Set 7 | tabialan
# City not found. Skipping...
# Processing Record 12 of Set 7 | mbandaka
# Processing Record 13 of Set 7 | burla
# Processing Record 14 of Set 7 | saldanha
# Processing Record 15 of Set 7 | akcakoca
# Processing Record 16 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 17 of Set 7 | poya
# Processing Record 18 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 19 of Set 7 | atasu
# Processing Record 20 of Set 7 | saint anthony
# Processing Record 21 of Set 7 | dongsheng
# Processing Record 22 of Set 7 | atherton
# Processing Record 23 of Set 7 | mendi
# Processing Record 24 of Set 7 | buala
# Processing Record 25 of Set 7 | bone
# Processing Record 26 of Set 7 | gimli
# Processing Record 27 of Set 7 | tongliao
# Processing Record 28 of Set 7 | gorontalo
# Processing Record 29 of Set 7 | makariv
# Processing Record 30 of Set 7 | shubarkuduk
# Processing Record 31 of Set 7 | deputatskiy
# Processing Record 32 of Set 7 | eyl
# Processing Record 33 of Set 7 | jinchang
# Processing Record 34 of Set 7 | laguna
# Processing Record 35 of Set 7 | umm lajj
# Processing Record 36 of Set 7 | tomohon
# Processing Record 37 of Set 7 | porto belo
# Processing Record 38 of Set 7 | camacha
# Processing Record 39 of Set 7 | cap malheureux
# Processing Record 40 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 7 | soubre
# Processing Record 42 of Set 7 | port blair
# Processing Record 43 of Set 7 | sovetskiy
# Processing Record 44 of Set 7 | jiuquan
# Processing Record 45 of Set 7 | lolua
# City not found. Skipping...
# Processing Record 46 of Set 7 | khorixas
# Processing Record 47 of Set 7 | juba
# Processing Record 48 of Set 7 | melita
# Processing Record 49 of Set 7 | maldonado
# Processing Record 50 of Set 7 | dalby
# Processing Record 1 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 2 of Set 8 | amga
# Processing Record 3 of Set 8 | roald
# Processing Record 4 of Set 8 | aberfeldy
# Processing Record 5 of Set 8 | charters towers
# Processing Record 6 of Set 8 | san luis
# Processing Record 7 of Set 8 | tuatapere
# Processing Record 8 of Set 8 | jiangyou
# Processing Record 9 of Set 8 | ilhabela
# Processing Record 10 of Set 8 | san-pedro
# Processing Record 11 of Set 8 | nemuro
# Processing Record 12 of Set 8 | shirokiy
# Processing Record 13 of Set 8 | chengde
# Processing Record 14 of Set 8 | bud
# Processing Record 15 of Set 8 | phuket
# Processing Record 16 of Set 8 | tokat
# Processing Record 17 of Set 8 | rovaniemi
# Processing Record 18 of Set 8 | pryazha
# Processing Record 19 of Set 8 | buraydah
# Processing Record 20 of Set 8 | ostrovnoy
# Processing Record 21 of Set 8 | mehamn
# Processing Record 22 of Set 8 | gunjur
# Processing Record 23 of Set 8 | santa isabel do rio negro
# Processing Record 24 of Set 8 | tual
# Processing Record 25 of Set 8 | manuk mangkaw
# Processing Record 26 of Set 8 | alto longa
# Processing Record 27 of Set 8 | vilcun
# Processing Record 28 of Set 8 | sattahip
# Processing Record 29 of Set 8 | kangaatsiaq
# Processing Record 30 of Set 8 | egvekinot
# Processing Record 31 of Set 8 | nanortalik
# Processing Record 32 of Set 8 | corinto
# Processing Record 33 of Set 8 | ust-ishim
# Processing Record 34 of Set 8 | victor harbor
# Processing Record 35 of Set 8 | cerro largo
# Processing Record 36 of Set 8 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 8 | verkhnevilyuysk
# Processing Record 39 of Set 8 | abu samrah
# Processing Record 40 of Set 8 | awbari
# Processing Record 41 of Set 8 | kargasok
# Processing Record 42 of Set 8 | playas
# Processing Record 43 of Set 8 | hilton head island
# Processing Record 44 of Set 8 | kuche
# City not found. Skipping...
# Processing Record 45 of Set 8 | porto empedocle
# Processing Record 46 of Set 8 | samarai
# Processing Record 47 of Set 8 | melfi
# Processing Record 48 of Set 8 | faanui
# Processing Record 49 of Set 8 | cayenne
# Processing Record 50 of Set 8 | haines junction
# Processing Record 1 of Set 9 | powell river
# Processing Record 2 of Set 9 | pascagoula
# Processing Record 3 of Set 9 | vanimo
# Processing Record 4 of Set 9 | samfya
# Processing Record 5 of Set 9 | lorengau
# Processing Record 6 of Set 9 | bam
# Processing Record 7 of Set 9 | cam ranh
# Processing Record 8 of Set 9 | mende
# Processing Record 9 of Set 9 | visnes
# Processing Record 10 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 11 of Set 9 | millinocket
# Processing Record 12 of Set 9 | springbok
# Processing Record 13 of Set 9 | kirkland lake
# Processing Record 14 of Set 9 | comodoro rivadavia
# Processing Record 15 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 16 of Set 9 | tarazona
# Processing Record 17 of Set 9 | murgab
# Processing Record 18 of Set 9 | leningradskiy
# Processing Record 19 of Set 9 | guiren
# Processing Record 20 of Set 9 | grand-santi
# Processing Record 21 of Set 9 | laredo
# Processing Record 22 of Set 9 | taoudenni
# Processing Record 23 of Set 9 | sibu
# Processing Record 24 of Set 9 | rawson
# Processing Record 25 of Set 9 | salalah
# Processing Record 26 of Set 9 | santo antonio de posse
# Processing Record 27 of Set 9 | conselheiro pena
# Processing Record 28 of Set 9 | zavyalovo
# Processing Record 29 of Set 9 | tiarei
# Processing Record 30 of Set 9 | elk city
# Processing Record 31 of Set 9 | kaeo
# Processing Record 32 of Set 9 | boa vista
# Processing Record 33 of Set 9 | talnakh
# Processing Record 34 of Set 9 | pavlodar
# Processing Record 35 of Set 9 | puerto madero
# Processing Record 36 of Set 9 | pokhara
# Processing Record 37 of Set 9 | beloha
# Processing Record 38 of Set 9 | quesnel
# Processing Record 39 of Set 9 | havelock
# Processing Record 40 of Set 9 | iracoubo
# Processing Record 41 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 42 of Set 9 | kiyasovo
# Processing Record 43 of Set 9 | mozarlandia
# Processing Record 44 of Set 9 | hit
# Processing Record 45 of Set 9 | inhambane
# Processing Record 46 of Set 9 | chermoz
# Processing Record 47 of Set 9 | bundibugyo
# Processing Record 48 of Set 9 | yulara
# Processing Record 49 of Set 9 | maymyo
# Processing Record 50 of Set 9 | hay river
# Processing Record 1 of Set 10 | muleba
# Processing Record 2 of Set 10 | shahr-e babak
# Processing Record 3 of Set 10 | madras
# Processing Record 4 of Set 10 | la solana
# Processing Record 5 of Set 10 | novovasylivka
# Processing Record 6 of Set 10 | srednekolymsk
# Processing Record 7 of Set 10 | torbay
# Processing Record 8 of Set 10 | dunedin
# Processing Record 9 of Set 10 | kyra
# Processing Record 10 of Set 10 | suzun
# Processing Record 11 of Set 10 | san cristobal
# Processing Record 12 of Set 10 | parkes
# Processing Record 13 of Set 10 | hami
# Processing Record 14 of Set 10 | ryotsu
# Processing Record 15 of Set 10 | keetmanshoop
# Processing Record 16 of Set 10 | mogadouro
# Processing Record 17 of Set 10 | itarema
# Processing Record 18 of Set 10 | hambantota
# Processing Record 19 of Set 10 | muravlenko
# Processing Record 20 of Set 10 | sutton coldfield
# Processing Record 21 of Set 10 | labuan
# Processing Record 22 of Set 10 | cockburn town
# Processing Record 23 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 24 of Set 10 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 10 | photharam
# Processing Record 26 of Set 10 | zhangye
# Processing Record 27 of Set 10 | aras
# Processing Record 28 of Set 10 | luderitz
# Processing Record 29 of Set 10 | rimbey
# Processing Record 30 of Set 10 | jiwani
# Processing Record 31 of Set 10 | acapulco
# Processing Record 32 of Set 10 | alice springs
# Processing Record 33 of Set 10 | biak
# Processing Record 34 of Set 10 | mackenzie
# Processing Record 35 of Set 10 | nioro
# Processing Record 36 of Set 10 | sambava
# Processing Record 37 of Set 10 | tobane
# Processing Record 38 of Set 10 | ukiah
# Processing Record 39 of Set 10 | lagos
# Processing Record 40 of Set 10 | bosaso
# Processing Record 41 of Set 10 | virtsu
# Processing Record 42 of Set 10 | tezu
# Processing Record 43 of Set 10 | lewistown
# Processing Record 44 of Set 10 | scarborough
# Processing Record 45 of Set 10 | banda aceh
# Processing Record 46 of Set 10 | saint-pierre
# Processing Record 47 of Set 10 | terrak
# Processing Record 48 of Set 10 | yichang
# Processing Record 49 of Set 10 | aasiaat
# Processing Record 50 of Set 10 | kavieng
# Processing Record 1 of Set 11 | mumford
# Processing Record 2 of Set 11 | coquimbo
# Processing Record 3 of Set 11 | aksu
# Processing Record 4 of Set 11 | ambikapur
# Processing Record 5 of Set 11 | storforshei
# Processing Record 6 of Set 11 | holme
# Processing Record 7 of Set 11 | le vauclin
# Processing Record 8 of Set 11 | tanout
# Processing Record 9 of Set 11 | sebinkarahisar
# Processing Record 10 of Set 11 | saint-joseph
# Processing Record 11 of Set 11 | ahuimanu
# Processing Record 12 of Set 11 | kirakira
# Processing Record 13 of Set 11 | manga
# Processing Record 14 of Set 11 | slave lake
# Processing Record 15 of Set 11 | macusani
# Processing Record 16 of Set 11 | parabel
# Processing Record 17 of Set 11 | hamilton
# Processing Record 18 of Set 11 | port hedland
# Processing Record 19 of Set 11 | victoria
# Processing Record 20 of Set 11 | la reforma
# Processing Record 21 of Set 11 | matadi
# Processing Record 22 of Set 11 | izhma
# Processing Record 23 of Set 11 | lhokseumawe
# Processing Record 24 of Set 11 | tallahassee
# Processing Record 25 of Set 11 | agirish
# Processing Record 26 of Set 11 | waddan
# Processing Record 27 of Set 11 | jalu
# Processing Record 28 of Set 11 | coromandel
# Processing Record 29 of Set 11 | kalevala
# Processing Record 30 of Set 11 | labutta
# City not found. Skipping...
# Processing Record 31 of Set 11 | olafsvik
# Processing Record 32 of Set 11 | daxian
# City not found. Skipping...
# Processing Record 33 of Set 11 | quatre cocos
# Processing Record 34 of Set 11 | evensk
# Processing Record 35 of Set 11 | kuna
# Processing Record 36 of Set 11 | mitu
# Processing Record 37 of Set 11 | paysandu
# Processing Record 38 of Set 11 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 39 of Set 11 | saint-francois
# Processing Record 40 of Set 11 | ilka
# City not found. Skipping...
# Processing Record 41 of Set 11 | manta
# Processing Record 42 of Set 11 | sao jose da coroa grande
# Processing Record 43 of Set 11 | kuusamo
# Processing Record 44 of Set 11 | hillsboro
# Processing Record 45 of Set 11 | matveyevka
# Processing Record 46 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 47 of Set 11 | formoso do araguaia
# City not found. Skipping...
# Processing Record 48 of Set 11 | eskil
# Processing Record 49 of Set 11 | ulladulla
# Processing Record 50 of Set 11 | san quintin
# Processing Record 1 of Set 12 | riverton
# Processing Record 2 of Set 12 | imeni poliny osipenko
# Processing Record 3 of Set 12 | luanda
# Processing Record 4 of Set 12 | samalaeulu
# City not found. Skipping...
# Processing Record 5 of Set 12 | dali
# Processing Record 6 of Set 12 | valparaiso
# Processing Record 7 of Set 12 | burley
# Processing Record 8 of Set 12 | sulurpeta
# City not found. Skipping...
# Processing Record 9 of Set 12 | bela
# Processing Record 10 of Set 12 | hendaye
# Processing Record 11 of Set 12 | lilongwe
# Processing Record 12 of Set 12 | cravo norte
# Processing Record 13 of Set 12 | dom pedrito
# Processing Record 14 of Set 12 | shihezi
# Processing Record 15 of Set 12 | taksimo
# Processing Record 16 of Set 12 | omachi
# Processing Record 17 of Set 12 | nalobikha
# Processing Record 18 of Set 12 | richards bay
# Processing Record 19 of Set 12 | senanga
# Processing Record 20 of Set 12 | bandarbeyla
# Processing Record 21 of Set 12 | gornopravdinsk
# Processing Record 22 of Set 12 | lagoa
# Processing Record 23 of Set 12 | olinda
# Processing Record 24 of Set 12 | mehran
# Processing Record 25 of Set 12 | uinskoye
# Processing Record 26 of Set 12 | beringovskiy
# Processing Record 27 of Set 12 | braganca
# Processing Record 28 of Set 12 | mullaitivu
# City not found. Skipping...
# Processing Record 29 of Set 12 | boddam
# Processing Record 30 of Set 12 | jatai
# Processing Record 31 of Set 12 | sur
# Processing Record 32 of Set 12 | narino
# Processing Record 33 of Set 12 | ponnani
# Processing Record 34 of Set 12 | martapura
# Processing Record 35 of Set 12 | wanlaweyn
# Processing Record 36 of Set 12 | lososina
# Processing Record 37 of Set 12 | ulhasnagar
# Processing Record 38 of Set 12 | katangli
# Processing Record 39 of Set 12 | grand island
# Processing Record 40 of Set 12 | kloulklubed
# Processing Record 41 of Set 12 | siimusti
# Processing Record 42 of Set 12 | kirillov
# Processing Record 43 of Set 12 | waingapu
# Processing Record 44 of Set 12 | ostuacan
# Processing Record 45 of Set 12 | eureka
# Processing Record 46 of Set 12 | raudeberg
# Processing Record 47 of Set 12 | tuy hoa
# Processing Record 48 of Set 12 | ozernovskiy
# Processing Record 49 of Set 12 | manacapuru
# Processing Record 50 of Set 12 | samusu
# City not found. Skipping...
# Processing Record 1 of Set 13 | vanavara
# Processing Record 2 of Set 13 | ancud
# Processing Record 3 of Set 13 | tateyama
# Processing Record 4 of Set 13 | nanga eboko
# Processing Record 5 of Set 13 | catuday
# Processing Record 6 of Set 13 | vicuna
# Processing Record 7 of Set 13 | kosgi
# City not found. Skipping...
# Processing Record 8 of Set 13 | bababe
# City not found. Skipping...
# Processing Record 9 of Set 13 | cullman
# Processing Record 10 of Set 13 | dortyol
# Processing Record 11 of Set 13 | huzhou
# Processing Record 12 of Set 13 | college
# Processing Record 13 of Set 13 | lahan
# Processing Record 14 of Set 13 | trairi
# Processing Record 15 of Set 13 | champerico
# Processing Record 16 of Set 13 | tomatlan
# Processing Record 17 of Set 13 | emerald
# Processing Record 18 of Set 13 | palana
# Processing Record 19 of Set 13 | izumo
# Processing Record 20 of Set 13 | yaan
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 567

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Alakurtti  66.9672   30.3491     42.64        91         100
# 1             Tiksi  71.6872  128.8694     28.60        81          92
# 2         Upernavik  72.7868  -56.1549     30.56        76         100
# 3             Pevek  69.7008  170.3133     25.95        90          98
# 4             Bluff -46.6000  168.3333     50.81        77         100
# 5             Paita  -5.0892  -81.1144     62.49        83           6
# 6           Rikitea -23.1203 -134.9692     72.82        70          30
# 7          Bengkulu  -3.8004  102.2655     82.60        77          37
# 8         Hithadhoo  -0.6000   73.0833     83.75        70          20
# 9  Praia Da Vitoria  38.7333  -27.0667     70.75        93          99
#
#    Wind Speed Country                 Date
# 0        3.11      RU  2021-10-03 06:11:02
# 1       15.01      RU  2021-10-03 06:09:30
# 2        8.12      GL  2021-10-03 06:08:32
# 3       13.96      RU  2021-10-03 06:10:14
# 4       13.65      NZ  2021-10-03 06:08:17
# 5        8.34      PE  2021-10-03 06:11:04
# 6       19.42      PF  2021-10-03 06:08:12
# 7        8.84      ID  2021-10-03 06:06:26
# 8       13.82      MV  2021-10-03 06:08:38
# 9        6.89      PT  2021-10-03 06:11:06

# %%
new_column_order = ['City','Country','Date','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed']
city_data_df=city_data_df[new_column_order]

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
