# %%
#Import pandas module
import pandas as pd

#Import the numpy module
import numpy as np

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
latitudes = []
longitudes = []
#Define function for generating latitude values

latitudes = np.random.uniform(-90.000, 90.000, size=2000)

longitudes = np.random.uniform(-180.000, 180.000, size=2000)

# %%
coordinates = list(zip(latitudes, longitudes))

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 757

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7a78aef3c21441b603da189739a03963

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    

    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_descrptn = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_descrptn})
    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | guerrero negro
# Processing Record 2 of Set 1 | san onofre
# Processing Record 3 of Set 1 | natal
# Processing Record 4 of Set 1 | hithadhoo
# Processing Record 5 of Set 1 | okhotsk
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | saint-pierre
# Processing Record 8 of Set 1 | keshod
# Processing Record 9 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 1 | mahebourg
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | lavrentiya
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 17 of Set 1 | vaini
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | saskylakh
# Processing Record 21 of Set 1 | hilo
# Processing Record 22 of Set 1 | katsuura
# Processing Record 23 of Set 1 | bhinmal
# Processing Record 24 of Set 1 | vila velha
# Processing Record 25 of Set 1 | mataura
# Processing Record 26 of Set 1 | nantucket
# Processing Record 27 of Set 1 | westport
# Processing Record 28 of Set 1 | cape town
# Processing Record 29 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 30 of Set 1 | blagodatnoye
# Processing Record 31 of Set 1 | victoria
# Processing Record 32 of Set 1 | lompoc
# Processing Record 33 of Set 1 | seoul
# Processing Record 34 of Set 1 | khorixas
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | kropotkin
# Processing Record 39 of Set 1 | hermanus
# Processing Record 40 of Set 1 | andros town
# Processing Record 41 of Set 1 | chimoio
# Processing Record 42 of Set 1 | kiunga
# Processing Record 43 of Set 1 | hakvik
# City not found. Skipping...
# Processing Record 44 of Set 1 | tuktoyaktuk
# Processing Record 45 of Set 1 | nouadhibou
# Processing Record 46 of Set 1 | new norfolk
# Processing Record 47 of Set 1 | podor
# Processing Record 48 of Set 1 | avarua
# Processing Record 49 of Set 1 | coihaique
# Processing Record 50 of Set 1 | hami
# Processing Record 1 of Set 2 | yellowknife
# Processing Record 2 of Set 2 | cabo san lucas
# Processing Record 3 of Set 2 | sisimiut
# Processing Record 4 of Set 2 | tessalit
# Processing Record 5 of Set 2 | sioux lookout
# Processing Record 6 of Set 2 | buckeye
# Processing Record 7 of Set 2 | aswan
# Processing Record 8 of Set 2 | kaeo
# Processing Record 9 of Set 2 | busselton
# Processing Record 10 of Set 2 | atasu
# Processing Record 11 of Set 2 | hillerod
# Processing Record 12 of Set 2 | moose factory
# Processing Record 13 of Set 2 | arona
# Processing Record 14 of Set 2 | ko samui
# Processing Record 15 of Set 2 | portland
# Processing Record 16 of Set 2 | severo-kurilsk
# Processing Record 17 of Set 2 | nabire
# Processing Record 18 of Set 2 | ilulissat
# Processing Record 19 of Set 2 | khatanga
# Processing Record 20 of Set 2 | santa fe
# Processing Record 21 of Set 2 | ushuaia
# Processing Record 22 of Set 2 | port elizabeth
# Processing Record 23 of Set 2 | tabas
# Processing Record 24 of Set 2 | lata
# Processing Record 25 of Set 2 | kapaa
# Processing Record 26 of Set 2 | kalmunai
# Processing Record 27 of Set 2 | chokurdakh
# Processing Record 28 of Set 2 | krasni okny
# Processing Record 29 of Set 2 | thompson
# Processing Record 30 of Set 2 | kawalu
# Processing Record 31 of Set 2 | puke
# Processing Record 32 of Set 2 | butaritari
# Processing Record 33 of Set 2 | dunedin
# Processing Record 34 of Set 2 | agadez
# Processing Record 35 of Set 2 | yar-sale
# Processing Record 36 of Set 2 | hobart
# Processing Record 37 of Set 2 | noumea
# Processing Record 38 of Set 2 | jieshi
# Processing Record 39 of Set 2 | constitucion
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | nanortalik
# Processing Record 42 of Set 2 | klaksvik
# Processing Record 43 of Set 2 | richard toll
# City not found. Skipping...
# Processing Record 44 of Set 2 | oltu
# Processing Record 45 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 2 | hobyo
# Processing Record 47 of Set 2 | kenai
# Processing Record 48 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 49 of Set 2 | avera
# Processing Record 50 of Set 2 | ambulu
# Processing Record 1 of Set 3 | barawe
# City not found. Skipping...
# Processing Record 2 of Set 3 | baillif
# Processing Record 3 of Set 3 | vila
# Processing Record 4 of Set 3 | yenagoa
# Processing Record 5 of Set 3 | zharkent
# Processing Record 6 of Set 3 | wuchang
# Processing Record 7 of Set 3 | merrill
# Processing Record 8 of Set 3 | oyon
# Processing Record 9 of Set 3 | hasaki
# Processing Record 10 of Set 3 | dzhusaly
# City not found. Skipping...
# Processing Record 11 of Set 3 | san quintin
# Processing Record 12 of Set 3 | devils lake
# Processing Record 13 of Set 3 | clyde river
# Processing Record 14 of Set 3 | tutoia
# Processing Record 15 of Set 3 | dikson
# Processing Record 16 of Set 3 | east london
# Processing Record 17 of Set 3 | kruisfontein
# Processing Record 18 of Set 3 | provideniya
# Processing Record 19 of Set 3 | puerto ayora
# Processing Record 20 of Set 3 | kiama
# Processing Record 21 of Set 3 | yabrud
# Processing Record 22 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | kaitangata
# Processing Record 25 of Set 3 | kisanga
# Processing Record 26 of Set 3 | ribeira grande
# Processing Record 27 of Set 3 | ambon
# Processing Record 28 of Set 3 | gamba
# Processing Record 29 of Set 3 | russell
# Processing Record 30 of Set 3 | aykhal
# Processing Record 31 of Set 3 | batagay-alyta
# Processing Record 32 of Set 3 | saint george
# Processing Record 33 of Set 3 | merauke
# Processing Record 34 of Set 3 | koutiala
# Processing Record 35 of Set 3 | chuy
# Processing Record 36 of Set 3 | santa cruz de tenerife
# Processing Record 37 of Set 3 | rorvik
# Processing Record 38 of Set 3 | cooma
# Processing Record 39 of Set 3 | eucaliptus
# Processing Record 40 of Set 3 | sao joao da barra
# Processing Record 41 of Set 3 | castro
# Processing Record 42 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 43 of Set 3 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 3 | hyeres
# Processing Record 45 of Set 3 | souris
# Processing Record 46 of Set 3 | torbay
# Processing Record 47 of Set 3 | gizel
# Processing Record 48 of Set 3 | arraial do cabo
# Processing Record 49 of Set 3 | bredasdorp
# Processing Record 50 of Set 3 | vestmannaeyjar
# Processing Record 1 of Set 4 | bundaberg
# Processing Record 2 of Set 4 | mount gambier
# Processing Record 3 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 4 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 5 of Set 4 | norman wells
# Processing Record 6 of Set 4 | labuhan
# Processing Record 7 of Set 4 | nome
# Processing Record 8 of Set 4 | leningradskiy
# Processing Record 9 of Set 4 | pevek
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | mount isa
# Processing Record 12 of Set 4 | panaba
# Processing Record 13 of Set 4 | kysyl-syr
# Processing Record 14 of Set 4 | karratha
# Processing Record 15 of Set 4 | pasni
# Processing Record 16 of Set 4 | upernavik
# Processing Record 17 of Set 4 | fort nelson
# Processing Record 18 of Set 4 | zahir pir
# Processing Record 19 of Set 4 | fortuna
# Processing Record 20 of Set 4 | nuuk
# Processing Record 21 of Set 4 | dwarka
# Processing Record 22 of Set 4 | lensk
# Processing Record 23 of Set 4 | ambatofinandrahana
# Processing Record 24 of Set 4 | tupik
# Processing Record 25 of Set 4 | awbari
# Processing Record 26 of Set 4 | kirovskiy
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | boyolangu
# Processing Record 29 of Set 4 | alta floresta
# Processing Record 30 of Set 4 | nalut
# Processing Record 31 of Set 4 | yatou
# Processing Record 32 of Set 4 | sterling
# Processing Record 33 of Set 4 | la primavera
# Processing Record 34 of Set 4 | tiksi
# Processing Record 35 of Set 4 | san policarpo
# Processing Record 36 of Set 4 | bandundu
# Processing Record 37 of Set 4 | tilichiki
# Processing Record 38 of Set 4 | rapar
# Processing Record 39 of Set 4 | denpasar
# Processing Record 40 of Set 4 | nikolskoye
# Processing Record 41 of Set 4 | hamilton
# Processing Record 42 of Set 4 | amapa
# Processing Record 43 of Set 4 | shelby
# Processing Record 44 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 4 | richards bay
# Processing Record 46 of Set 4 | xinzhi
# Processing Record 47 of Set 4 | arboledas
# Processing Record 48 of Set 4 | monster
# Processing Record 49 of Set 4 | imeni poliny osipenko
# Processing Record 50 of Set 4 | puerto del rosario
# Processing Record 1 of Set 5 | orlik
# Processing Record 2 of Set 5 | tanout
# Processing Record 3 of Set 5 | isangel
# Processing Record 4 of Set 5 | ngukurr
# City not found. Skipping...
# Processing Record 5 of Set 5 | smidovich
# Processing Record 6 of Set 5 | kavieng
# Processing Record 7 of Set 5 | lebu
# Processing Record 8 of Set 5 | saldanha
# Processing Record 9 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 10 of Set 5 | lewiston
# Processing Record 11 of Set 5 | chiang rai
# Processing Record 12 of Set 5 | pangnirtung
# Processing Record 13 of Set 5 | ampanihy
# Processing Record 14 of Set 5 | dingle
# Processing Record 15 of Set 5 | santa marta
# Processing Record 16 of Set 5 | meulaboh
# Processing Record 17 of Set 5 | kandrian
# Processing Record 18 of Set 5 | karpathos
# Processing Record 19 of Set 5 | cockburn town
# Processing Record 20 of Set 5 | vostok
# Processing Record 21 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 22 of Set 5 | verkhnyaya inta
# Processing Record 23 of Set 5 | quatre cocos
# Processing Record 24 of Set 5 | souillac
# Processing Record 25 of Set 5 | yerofey pavlovich
# Processing Record 26 of Set 5 | akyab
# Processing Record 27 of Set 5 | touros
# Processing Record 28 of Set 5 | nyurba
# Processing Record 29 of Set 5 | sinjai
# Processing Record 30 of Set 5 | blagoyevo
# Processing Record 31 of Set 5 | kostolac
# Processing Record 32 of Set 5 | bengkulu
# Processing Record 33 of Set 5 | longyearbyen
# Processing Record 34 of Set 5 | kieta
# Processing Record 35 of Set 5 | airai
# Processing Record 36 of Set 5 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 5 | bam
# Processing Record 38 of Set 5 | alangilan
# Processing Record 39 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 5 | ust-kuyga
# Processing Record 41 of Set 5 | coquimbo
# Processing Record 42 of Set 5 | chau doc
# Processing Record 43 of Set 5 | ibb
# Processing Record 44 of Set 5 | tignere
# Processing Record 45 of Set 5 | newberry
# Processing Record 46 of Set 5 | san cristobal
# Processing Record 47 of Set 5 | bambous virieux
# Processing Record 48 of Set 5 | acarau
# Processing Record 49 of Set 5 | laguna
# Processing Record 50 of Set 5 | maragogi
# Processing Record 1 of Set 6 | bathsheba
# Processing Record 2 of Set 6 | ostrovnoy
# Processing Record 3 of Set 6 | genhe
# Processing Record 4 of Set 6 | sangamner
# Processing Record 5 of Set 6 | keti bandar
# Processing Record 6 of Set 6 | northam
# Processing Record 7 of Set 6 | aklavik
# Processing Record 8 of Set 6 | salinopolis
# Processing Record 9 of Set 6 | morant bay
# Processing Record 10 of Set 6 | jiuquan
# Processing Record 11 of Set 6 | saint-philippe
# Processing Record 12 of Set 6 | lokot
# Processing Record 13 of Set 6 | qaanaaq
# Processing Record 14 of Set 6 | georgetown
# Processing Record 15 of Set 6 | mitsamiouli
# Processing Record 16 of Set 6 | padang
# Processing Record 17 of Set 6 | glendive
# Processing Record 18 of Set 6 | manggar
# Processing Record 19 of Set 6 | port blair
# Processing Record 20 of Set 6 | honiara
# Processing Record 21 of Set 6 | port hardy
# Processing Record 22 of Set 6 | tasiilaq
# Processing Record 23 of Set 6 | sabha
# Processing Record 24 of Set 6 | kirakira
# Processing Record 25 of Set 6 | prieska
# Processing Record 26 of Set 6 | hervey bay
# Processing Record 27 of Set 6 | chapais
# Processing Record 28 of Set 6 | tuatapere
# Processing Record 29 of Set 6 | srednekolymsk
# Processing Record 30 of Set 6 | pangai
# Processing Record 31 of Set 6 | acapulco
# Processing Record 32 of Set 6 | fairbanks
# Processing Record 33 of Set 6 | warrnambool
# Processing Record 34 of Set 6 | port lincoln
# Processing Record 35 of Set 6 | asbestovskiy
# Processing Record 36 of Set 6 | pacific grove
# Processing Record 37 of Set 6 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 6 | ciudad bolivar
# Processing Record 39 of Set 6 | porto murtinho
# Processing Record 40 of Set 6 | zhuhai
# Processing Record 41 of Set 6 | berlin
# Processing Record 42 of Set 6 | katete
# Processing Record 43 of Set 6 | miles city
# Processing Record 44 of Set 6 | sechura
# Processing Record 45 of Set 6 | eirunepe
# Processing Record 46 of Set 6 | sao filipe
# Processing Record 47 of Set 6 | sao gabriel da cachoeira
# Processing Record 48 of Set 6 | gresham
# Processing Record 49 of Set 6 | mayo
# Processing Record 50 of Set 6 | te anau
# Processing Record 1 of Set 7 | san patricio
# Processing Record 2 of Set 7 | tawkar
# City not found. Skipping...
# Processing Record 3 of Set 7 | prabumulih
# Processing Record 4 of Set 7 | wanlaweyn
# Processing Record 5 of Set 7 | mirnyy
# Processing Record 6 of Set 7 | cherskiy
# Processing Record 7 of Set 7 | jinchang
# Processing Record 8 of Set 7 | havoysund
# Processing Record 9 of Set 7 | tateyama
# Processing Record 10 of Set 7 | dongsheng
# Processing Record 11 of Set 7 | ponta do sol
# Processing Record 12 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 13 of Set 7 | ancud
# Processing Record 14 of Set 7 | riyadh
# Processing Record 15 of Set 7 | sao raimundo nonato
# Processing Record 16 of Set 7 | khandbari
# Processing Record 17 of Set 7 | vestmanna
# Processing Record 18 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 7 | byron bay
# Processing Record 20 of Set 7 | tomatlan
# Processing Record 21 of Set 7 | port moresby
# Processing Record 22 of Set 7 | mountain home
# Processing Record 23 of Set 7 | salinas
# Processing Record 24 of Set 7 | poum
# Processing Record 25 of Set 7 | narsipatnam
# Processing Record 26 of Set 7 | deputatskiy
# Processing Record 27 of Set 7 | polunochnoye
# Processing Record 28 of Set 7 | spring hill
# Processing Record 29 of Set 7 | la ronge
# Processing Record 30 of Set 7 | hambantota
# Processing Record 31 of Set 7 | chinhoyi
# Processing Record 32 of Set 7 | rome
# Processing Record 33 of Set 7 | kayerkan
# Processing Record 34 of Set 7 | umm kaddadah
# Processing Record 35 of Set 7 | kargasok
# Processing Record 36 of Set 7 | sindor
# Processing Record 37 of Set 7 | pinyug
# Processing Record 38 of Set 7 | hvolsvollur
# Processing Record 39 of Set 7 | buala
# Processing Record 40 of Set 7 | vieques
# Processing Record 41 of Set 7 | yarim
# Processing Record 42 of Set 7 | kosh-agach
# Processing Record 43 of Set 7 | linjiang
# Processing Record 44 of Set 7 | grand gaube
# Processing Record 45 of Set 7 | algiers
# Processing Record 46 of Set 7 | newport
# Processing Record 47 of Set 7 | ann arbor
# Processing Record 48 of Set 7 | cabangan
# Processing Record 49 of Set 7 | tsiroanomandidy
# Processing Record 50 of Set 7 | huarmey
# Processing Record 1 of Set 8 | coahuayana
# Processing Record 2 of Set 8 | te karaka
# Processing Record 3 of Set 8 | nizhniy kuranakh
# Processing Record 4 of Set 8 | placido de castro
# Processing Record 5 of Set 8 | berlevag
# Processing Record 6 of Set 8 | henties bay
# Processing Record 7 of Set 8 | wanaka
# Processing Record 8 of Set 8 | marawi
# Processing Record 9 of Set 8 | sitka
# Processing Record 10 of Set 8 | kahului
# Processing Record 11 of Set 8 | anadyr
# Processing Record 12 of Set 8 | neuquen
# Processing Record 13 of Set 8 | sao felix do xingu
# Processing Record 14 of Set 8 | siniscola
# Processing Record 15 of Set 8 | guymon
# Processing Record 16 of Set 8 | macaboboni
# City not found. Skipping...
# Processing Record 17 of Set 8 | marsa matruh
# Processing Record 18 of Set 8 | talnakh
# Processing Record 19 of Set 8 | chara
# Processing Record 20 of Set 8 | alexandria
# Processing Record 21 of Set 8 | naze
# Processing Record 22 of Set 8 | illela
# Processing Record 23 of Set 8 | adil-yangiyurt
# Processing Record 24 of Set 8 | eganville
# Processing Record 25 of Set 8 | millinocket
# Processing Record 26 of Set 8 | qandala
# Processing Record 27 of Set 8 | cidreira
# Processing Record 28 of Set 8 | kalanguy
# Processing Record 29 of Set 8 | mae sot
# Processing Record 30 of Set 8 | puerto el triunfo
# Processing Record 31 of Set 8 | tiznit
# Processing Record 32 of Set 8 | erenhot
# Processing Record 33 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 34 of Set 8 | abu samrah
# Processing Record 35 of Set 8 | battle creek
# Processing Record 36 of Set 8 | sakakah
# Processing Record 37 of Set 8 | plouzane
# Processing Record 38 of Set 8 | sinnamary
# Processing Record 39 of Set 8 | posse
# Processing Record 40 of Set 8 | fuyang
# Processing Record 41 of Set 8 | kousseri
# Processing Record 42 of Set 8 | aksarka
# Processing Record 43 of Set 8 | saalfeld
# Processing Record 44 of Set 8 | nayoro
# Processing Record 45 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 46 of Set 8 | dehloran
# Processing Record 47 of Set 8 | namatanai
# Processing Record 48 of Set 8 | key largo
# Processing Record 49 of Set 8 | abu kamal
# Processing Record 50 of Set 8 | mwene-ditu
# Processing Record 1 of Set 9 | comodoro rivadavia
# Processing Record 2 of Set 9 | providencia
# Processing Record 3 of Set 9 | grand-santi
# Processing Record 4 of Set 9 | santa maria
# Processing Record 5 of Set 9 | pangkalanbuun
# Processing Record 6 of Set 9 | narsaq
# Processing Record 7 of Set 9 | calabozo
# Processing Record 8 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 9 of Set 9 | saint-augustin
# Processing Record 10 of Set 9 | vila franca do campo
# Processing Record 11 of Set 9 | bubaque
# Processing Record 12 of Set 9 | husavik
# Processing Record 13 of Set 9 | stornoway
# Processing Record 14 of Set 9 | mursalimkino
# Processing Record 15 of Set 9 | belmonte
# Processing Record 16 of Set 9 | oranjemund
# Processing Record 17 of Set 9 | dubreka
# Processing Record 18 of Set 9 | phuntsholing
# Processing Record 19 of Set 9 | brae
# Processing Record 20 of Set 9 | arosa
# Processing Record 21 of Set 9 | makat
# Processing Record 22 of Set 9 | ekibastuz
# Processing Record 23 of Set 9 | lorengau
# Processing Record 24 of Set 9 | tabou
# Processing Record 25 of Set 9 | turochak
# Processing Record 26 of Set 9 | itoman
# Processing Record 27 of Set 9 | los llanos de aridane
# Processing Record 28 of Set 9 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 9 | sabang
# Processing Record 30 of Set 9 | korla
# Processing Record 31 of Set 9 | urdzhar
# City not found. Skipping...
# Processing Record 32 of Set 9 | barra patuca
# Processing Record 33 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 9 | cangas
# Processing Record 35 of Set 9 | lufkin
# Processing Record 36 of Set 9 | ugoofaaru
# Processing Record 37 of Set 9 | bethal
# Processing Record 38 of Set 9 | andevoranto
# City not found. Skipping...
# Processing Record 39 of Set 9 | hovd
# Processing Record 40 of Set 9 | maxixe
# Processing Record 41 of Set 9 | pemangkat
# Processing Record 42 of Set 9 | ambilobe
# Processing Record 43 of Set 9 | bandarbeyla
# Processing Record 44 of Set 9 | visby
# Processing Record 45 of Set 9 | sataua
# City not found. Skipping...
# Processing Record 46 of Set 9 | pozo colorado
# Processing Record 47 of Set 9 | san jeronimo
# Processing Record 48 of Set 9 | tiquisate
# Processing Record 49 of Set 9 | garcovu
# City not found. Skipping...
# Processing Record 50 of Set 9 | makakilo city
# Processing Record 1 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 2 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 10 | sur
# Processing Record 4 of Set 10 | college
# Processing Record 5 of Set 10 | salalah
# Processing Record 6 of Set 10 | tubruq
# City not found. Skipping...
# Processing Record 7 of Set 10 | terrace
# Processing Record 8 of Set 10 | alausi
# Processing Record 9 of Set 10 | arlit
# Processing Record 10 of Set 10 | biltine
# Processing Record 11 of Set 10 | port macquarie
# Processing Record 12 of Set 10 | beled
# Processing Record 13 of Set 10 | alcudia
# Processing Record 14 of Set 10 | tura
# Processing Record 15 of Set 10 | matara
# Processing Record 16 of Set 10 | ahipara
# Processing Record 17 of Set 10 | belle glade
# Processing Record 18 of Set 10 | tortoli
# Processing Record 19 of Set 10 | vardo
# Processing Record 20 of Set 10 | medicine hat
# Processing Record 21 of Set 10 | hualmay
# Processing Record 22 of Set 10 | lafayette
# Processing Record 23 of Set 10 | mount pleasant
# Processing Record 24 of Set 10 | lapovo
# Processing Record 25 of Set 10 | yidu
# Processing Record 26 of Set 10 | aripuana
# Processing Record 27 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 28 of Set 10 | geraldton
# Processing Record 29 of Set 10 | sarakhs
# Processing Record 30 of Set 10 | kungurtug
# Processing Record 31 of Set 10 | rabo de peixe
# Processing Record 32 of Set 10 | maceio
# Processing Record 33 of Set 10 | gat
# Processing Record 34 of Set 10 | bairiki
# Processing Record 35 of Set 10 | margate
# Processing Record 36 of Set 10 | burica
# City not found. Skipping...
# Processing Record 37 of Set 10 | san ignacio
# Processing Record 38 of Set 10 | tevriz
# Processing Record 39 of Set 10 | nusaybin
# Processing Record 40 of Set 10 | dongkan
# Processing Record 41 of Set 10 | kidal
# Processing Record 42 of Set 10 | ulladulla
# Processing Record 43 of Set 10 | kindersley
# Processing Record 44 of Set 10 | garmsar
# Processing Record 45 of Set 10 | horadiz
# Processing Record 46 of Set 10 | tidore
# City not found. Skipping...
# Processing Record 47 of Set 10 | honjo
# Processing Record 48 of Set 10 | cadillac
# Processing Record 49 of Set 10 | cuautlapan
# Processing Record 50 of Set 10 | ketchikan
# Processing Record 1 of Set 11 | hatillo
# Processing Record 2 of Set 11 | codrington
# Processing Record 3 of Set 11 | nadvoitsy
# Processing Record 4 of Set 11 | viedma
# Processing Record 5 of Set 11 | komsomolskiy
# Processing Record 6 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 7 of Set 11 | san miguel
# Processing Record 8 of Set 11 | kaiwaka
# Processing Record 9 of Set 11 | sabzevar
# Processing Record 10 of Set 11 | eyl
# Processing Record 11 of Set 11 | buluang
# Processing Record 12 of Set 11 | bilma
# Processing Record 13 of Set 11 | buraydah
# Processing Record 14 of Set 11 | ixtapa
# Processing Record 15 of Set 11 | faanui
# Processing Record 16 of Set 11 | flinders
# Processing Record 17 of Set 11 | bonthe
# Processing Record 18 of Set 11 | baracoa
# Processing Record 19 of Set 11 | san matias
# Processing Record 20 of Set 11 | dinguiraye
# Processing Record 21 of Set 11 | amarante do maranhao
# Processing Record 22 of Set 11 | bulembu
# Processing Record 23 of Set 11 | leninskoye
# Processing Record 24 of Set 11 | porto nacional
# Processing Record 25 of Set 11 | san juan
# Processing Record 26 of Set 11 | bellevue
# Processing Record 27 of Set 11 | erhlin
# City not found. Skipping...
# Processing Record 28 of Set 11 | songjianghe
# Processing Record 29 of Set 11 | kholm
# Processing Record 30 of Set 11 | yulara
# Processing Record 31 of Set 11 | rostovka
# Processing Record 32 of Set 11 | nouakchott
# Processing Record 33 of Set 11 | gushikawa
# Processing Record 34 of Set 11 | kamenka
# Processing Record 35 of Set 11 | vanavara
# Processing Record 36 of Set 11 | saint anthony
# Processing Record 37 of Set 11 | nizhnyaya tura
# Processing Record 38 of Set 11 | naftah
# City not found. Skipping...
# Processing Record 39 of Set 11 | nuevo progreso
# Processing Record 40 of Set 11 | plettenberg bay
# Processing Record 41 of Set 11 | pestravka
# Processing Record 42 of Set 11 | kapoeta
# Processing Record 43 of Set 11 | racconigi
# Processing Record 44 of Set 11 | kikwit
# Processing Record 45 of Set 11 | huambo
# Processing Record 46 of Set 11 | bandarban
# Processing Record 47 of Set 11 | biak
# Processing Record 48 of Set 11 | kaz
# Processing Record 49 of Set 11 | torbat-e jam
# Processing Record 50 of Set 11 | asht
# City not found. Skipping...
# Processing Record 1 of Set 12 | grindavik
# Processing Record 2 of Set 12 | emmett
# Processing Record 3 of Set 12 | luwuk
# Processing Record 4 of Set 12 | beringovskiy
# Processing Record 5 of Set 12 | san juan de opoa
# Processing Record 6 of Set 12 | baykit
# Processing Record 7 of Set 12 | kabo
# Processing Record 8 of Set 12 | sandy bay
# Processing Record 9 of Set 12 | vyartsilya
# Processing Record 10 of Set 12 | praia da vitoria
# Processing Record 11 of Set 12 | dunda
# Processing Record 12 of Set 12 | barvinkove
# Processing Record 13 of Set 12 | klyuchi
# Processing Record 14 of Set 12 | orumiyeh
# Processing Record 15 of Set 12 | cedar city
# Processing Record 16 of Set 12 | dudinka
# Processing Record 17 of Set 12 | khuzdar
# Processing Record 18 of Set 12 | asau
# Processing Record 19 of Set 12 | nancha
# Processing Record 20 of Set 12 | progreso
# Processing Record 21 of Set 12 | lazaro cardenas
# Processing Record 22 of Set 12 | bilibino
# Processing Record 23 of Set 12 | karla
# Processing Record 24 of Set 12 | lagoa
# Processing Record 25 of Set 12 | atar
# Processing Record 26 of Set 12 | gazanjyk
# Processing Record 27 of Set 12 | hirara
# Processing Record 28 of Set 12 | distraccion
# Processing Record 29 of Set 12 | itaunja
# Processing Record 30 of Set 12 | port hedland
# Processing Record 31 of Set 12 | jalu
# Processing Record 32 of Set 12 | tiverton
# Processing Record 33 of Set 12 | danilov
# Processing Record 34 of Set 12 | half moon bay
# Processing Record 35 of Set 12 | ormara
# Processing Record 36 of Set 12 | christiansfeld
# Processing Record 37 of Set 12 | jega
# Processing Record 38 of Set 12 | zheleznodorozhnyy
# Processing Record 39 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 12 | ushtobe
# Processing Record 41 of Set 12 | krasnovishersk
# Processing Record 42 of Set 12 | alofi
# Processing Record 43 of Set 12 | makarov
# Processing Record 44 of Set 12 | roald
# Processing Record 45 of Set 12 | mahibadhoo
# Processing Record 46 of Set 12 | porto velho
# Processing Record 47 of Set 12 | mattru
# Processing Record 48 of Set 12 | kaharlyk
# Processing Record 49 of Set 12 | quang ngai
# Processing Record 50 of Set 12 | opobo
# City not found. Skipping...
# Processing Record 1 of Set 13 | upington
# Processing Record 2 of Set 13 | chipinge
# Processing Record 3 of Set 13 | shieli
# Processing Record 4 of Set 13 | iqaluit
# Processing Record 5 of Set 13 | shimoda
# Processing Record 6 of Set 13 | maracaju
# Processing Record 7 of Set 13 | paamiut
# Processing Record 8 of Set 13 | uruzgan
# Processing Record 9 of Set 13 | esperance
# Processing Record 10 of Set 13 | alghero
# Processing Record 11 of Set 13 | mercedes
# Processing Record 12 of Set 13 | zaranj
# Processing Record 13 of Set 13 | pangody
# Processing Record 14 of Set 13 | villa carlos paz
# Processing Record 15 of Set 13 | bow island
# Processing Record 16 of Set 13 | urusha
# Processing Record 17 of Set 13 | el alto
# Processing Record 18 of Set 13 | teguise
# Processing Record 19 of Set 13 | outjo
# Processing Record 20 of Set 13 | urumqi
# Processing Record 21 of Set 13 | sangar
# Processing Record 22 of Set 13 | umm lajj
# Processing Record 23 of Set 13 | banjar
# Processing Record 24 of Set 13 | khonuu
# City not found. Skipping...
# Processing Record 25 of Set 13 | muros
# Processing Record 26 of Set 13 | sorland
# Processing Record 27 of Set 13 | tshikapa
# Processing Record 28 of Set 13 | auki
# Processing Record 29 of Set 13 | kodinsk
# Processing Record 30 of Set 13 | kavaratti
# Processing Record 31 of Set 13 | hit
# Processing Record 32 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 33 of Set 13 | ukiah
# Processing Record 34 of Set 13 | fallon
# Processing Record 35 of Set 13 | hay river
# Processing Record 36 of Set 13 | kiruna
# Processing Record 37 of Set 13 | waingapu
# Processing Record 38 of Set 13 | pisco
# Processing Record 39 of Set 13 | adrar
# Processing Record 40 of Set 13 | fare
# Processing Record 41 of Set 13 | resistencia
# Processing Record 42 of Set 13 | esmeraldas
# Processing Record 43 of Set 13 | chambersburg
# Processing Record 44 of Set 13 | krasnyy kut
# Processing Record 45 of Set 13 | chimbote
# Processing Record 46 of Set 13 | shingu
# Processing Record 47 of Set 13 | chilca
# Processing Record 48 of Set 13 | glubokoe
# City not found. Skipping...
# Processing Record 49 of Set 13 | nkayi
# Processing Record 50 of Set 13 | sai buri
# Processing Record 1 of Set 14 | odugathur
# City not found. Skipping...
# Processing Record 2 of Set 14 | abu dhabi
# Processing Record 3 of Set 14 | shaartuz
# City not found. Skipping...
# Processing Record 4 of Set 14 | elko
# Processing Record 5 of Set 14 | opuwo
# Processing Record 6 of Set 14 | juifang
# City not found. Skipping...
# Processing Record 7 of Set 14 | kendari
# Processing Record 8 of Set 14 | sembe
# Processing Record 9 of Set 14 | bonavista
# Processing Record 10 of Set 14 | aksu
# Processing Record 11 of Set 14 | oksfjord
# Processing Record 12 of Set 14 | cabras
# Processing Record 13 of Set 14 | riverton
# Processing Record 14 of Set 14 | ishinomaki
# Processing Record 15 of Set 14 | prince rupert
# Processing Record 16 of Set 14 | saiha
# Processing Record 17 of Set 14 | svetlaya
# Processing Record 18 of Set 14 | landskrona
# Processing Record 19 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 20 of Set 14 | camalu
# Processing Record 21 of Set 14 | serik
# Processing Record 22 of Set 14 | emba
# Processing Record 23 of Set 14 | tavda
# Processing Record 24 of Set 14 | bowen
# Processing Record 25 of Set 14 | octeville
# Processing Record 26 of Set 14 | baisha
# Processing Record 27 of Set 14 | stoyba
# City not found. Skipping...
# Processing Record 28 of Set 14 | bone
# Processing Record 29 of Set 14 | yumen
# Processing Record 30 of Set 14 | cuamba
# Processing Record 31 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 32 of Set 14 | peniche
# Processing Record 33 of Set 14 | vozrozhdeniye
# Processing Record 34 of Set 14 | tucumcari
# Processing Record 35 of Set 14 | qasigiannguit
# Processing Record 36 of Set 14 | saint-francois
# Processing Record 37 of Set 14 | wakkanai
# Processing Record 38 of Set 14 | tezu
# Processing Record 39 of Set 14 | bressuire
# Processing Record 40 of Set 14 | marzuq
# Processing Record 41 of Set 14 | makinsk
# Processing Record 42 of Set 14 | aconibe
# Processing Record 43 of Set 14 | sri aman
# Processing Record 44 of Set 14 | hofn
# Processing Record 45 of Set 14 | governador valadares
# Processing Record 46 of Set 14 | houston
# Processing Record 47 of Set 14 | volot
# Processing Record 48 of Set 14 | fayaoue
# Processing Record 49 of Set 14 | acuna
# City not found. Skipping...
# Processing Record 50 of Set 14 | tatui
# Processing Record 1 of Set 15 | sarankhola
# Processing Record 2 of Set 15 | challans
# Processing Record 3 of Set 15 | katobu
# Processing Record 4 of Set 15 | elizabeth city
# Processing Record 5 of Set 15 | ebolowa
# Processing Record 6 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 15 | baoshan
# Processing Record 8 of Set 15 | jaca
# Processing Record 9 of Set 15 | cairns
# Processing Record 10 of Set 15 | gudari
# Processing Record 11 of Set 15 | kailua
# Processing Record 12 of Set 15 | porsa
# Processing Record 13 of Set 15 | segou
# Processing Record 14 of Set 15 | mao
# Processing Record 15 of Set 15 | serenje
# Processing Record 16 of Set 15 | yara
# Processing Record 17 of Set 15 | bulaevo
# Processing Record 18 of Set 15 | oistins
# Processing Record 19 of Set 15 | narasannapeta
# Processing Record 20 of Set 15 | piltene
# Processing Record 21 of Set 15 | altamont
# Processing Record 22 of Set 15 | tabialan
# City not found. Skipping...
# Processing Record 23 of Set 15 | ilula
# Processing Record 24 of Set 15 | krasnogvardeyskoye
# Processing Record 25 of Set 15 | ramsar
# Processing Record 26 of Set 15 | sisophon
# Processing Record 27 of Set 15 | mandalgovi
# Processing Record 28 of Set 15 | florianopolis
# Processing Record 29 of Set 15 | wulanhaote
# City not found. Skipping...
# Processing Record 30 of Set 15 | sola
# Processing Record 31 of Set 15 | ilebo
# Processing Record 32 of Set 15 | santa cruz
# Processing Record 33 of Set 15 | chicama
# Processing Record 34 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 15 | taoudenni
# Processing Record 36 of Set 15 | qaqortoq
# Processing Record 37 of Set 15 | labutta
# City not found. Skipping...
# Processing Record 38 of Set 15 | port-gentil
# Processing Record 39 of Set 15 | ginda
# Processing Record 40 of Set 15 | egvekinot
# Processing Record 41 of Set 15 | kimbe
# Processing Record 42 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 44 of Set 15 | manzanillo
# Processing Record 45 of Set 15 | cocorit
# Processing Record 46 of Set 15 | ust-ishim
# Processing Record 47 of Set 15 | wahiawa
# Processing Record 48 of Set 15 | porterville
# Processing Record 49 of Set 15 | tigwi
# City not found. Skipping...
# Processing Record 50 of Set 15 | atka
# City not found. Skipping...
# Processing Record 1 of Set 16 | rio gallegos
# Processing Record 2 of Set 16 | kangaatsiaq
# Processing Record 3 of Set 16 | taihe
# Processing Record 4 of Set 16 | hachinohe
# Processing Record 5 of Set 16 | powell river
# Processing Record 6 of Set 16 | bera
# Processing Record 7 of Set 16 | unhel
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 692

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Guerrero Negro      MX  27.9769 -114.0611     70.30        76           1
# 1      San Onofre      CO   9.7359  -75.5263     77.45        92         100
# 2           Natal      BR  -5.7950  -35.2094     79.02        83          20
# 3       Hithadhoo      MV  -0.6000   73.0833     83.48        76          90
# 4         Okhotsk      RU  59.3833  143.3000     34.75        65          61
# 5    Saint-Pierre      RE -21.3393   55.4781     76.68        70           0
# 6          Keshod      IN  21.3000   70.2500     88.68        62          83
# 7       Mahebourg      MU -20.4081   57.7000     77.29        69          75
# 8          Atuona      PF  -9.8000 -139.0333     78.21        79           9
# 9    Punta Arenas      CL -53.1500  -70.9167     41.11        65           0
#
#    Wind Speed Current Description
# 0       14.16           clear sky
# 1        3.18     overcast clouds
# 2        8.05          few clouds
# 3       14.47     overcast clouds
# 4       14.94       broken clouds
# 5        5.75           clear sky
# 6        7.85       broken clouds
# 7        8.05       broken clouds
# 8       21.56           clear sky
# 9       13.80           clear sky

# %%
column_order = ['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df=city_data_df[column_order]

# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
